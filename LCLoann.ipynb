# %%
import pandas as pd

# Specify the file path

file_path = r"C:\Users\pc\Desktop\Data science & AI\Data science\Python\csv\LCLoanData\LoanStats3a.csv"
pd.set_option('display.max_columns', None) 

df = pd.read_csv(file_path, header=1)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2599159068.py:8: DtypeWarning: Columns (0,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, header=1)

# %%
df
# Out:
#                                                     id  member_id  loan_amnt  \
# 0                                                  NaN        NaN     5000.0
# 1                                                  NaN        NaN     2500.0
# 2                                                  NaN        NaN     2400.0
# 3                                                  NaN        NaN    10000.0
# 4                                                  NaN        NaN     3000.0
# ...                                                ...        ...        ...
# 42537                                              NaN        NaN     5000.0
# 42538                                              NaN        NaN        NaN
# 42539                                              NaN        NaN        NaN
# 42540  Total amount funded in policy code 1: 460296150        NaN        NaN
# 42541          Total amount funded in policy code 2: 0        NaN        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42542 entries, 0 to 42541
# Columns: 145 entries, id to settlement_term
# dtypes: float64(115), object(30)
# memory usage: 47.1+ MB

# %%
threshold = 0.3 * len(df)
print(threshold)
# Out:
# 12762.6

# %%
len(df)
# Out:
# 42542

# %%
df["id"].isnull()
df
# Out:
#                                                     id  member_id  loan_amnt  \
# 0                                                  NaN        NaN     5000.0
# 1                                                  NaN        NaN     2500.0
# 2                                                  NaN        NaN     2400.0
# 3                                                  NaN        NaN    10000.0
# 4                                                  NaN        NaN     3000.0
# ...                                                ...        ...        ...
# 42537                                              NaN        NaN     5000.0
# 42538                                              NaN        NaN        NaN
# 42539                                              NaN        NaN        NaN
# 42540  Total amount funded in policy code 1: 460296150        NaN        NaN
# 42541          Total amount funded in policy code 2: 0        NaN        NaN
#
# ...

# %%
df.drop(["id"], axis=1, inplace=True)

# %%
df
# Out:
#        member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0            NaN     5000.0       5000.0           4975.0   36 months
# 1            NaN     2500.0       2500.0           2500.0   60 months
# 2            NaN     2400.0       2400.0           2400.0   36 months
# 3            NaN    10000.0      10000.0          10000.0   36 months
# 4            NaN     3000.0       3000.0           3000.0   60 months
# ...          ...        ...          ...              ...         ...
# 42537        NaN     5000.0       5000.0              0.0   36 months
# 42538        NaN        NaN          NaN              NaN         NaN
# 42539        NaN        NaN          NaN              NaN         NaN
# 42540        NaN        NaN          NaN              NaN         NaN
# 42541        NaN        NaN          NaN              NaN         NaN
#
#       int_rate  installment grade sub_grade                 emp_title  \
# ...

# %%
threshold = 0.3 * len(df)

# Drop columns with 30% or more null values
df.dropna(axis=1, thresh=threshold, inplace=True)

# %%
df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         5000.0       5000.0           4975.0   36 months   10.65%
# 1         2500.0       2500.0           2500.0   60 months   15.27%
# 2         2400.0       2400.0           2400.0   36 months   15.96%
# 3        10000.0      10000.0          10000.0   36 months   13.49%
# 4         3000.0       3000.0           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 42537     5000.0       5000.0              0.0   36 months    7.75%
# 42538        NaN          NaN              NaN         NaN      NaN
# 42539        NaN          NaN              NaN         NaN      NaN
# 42540        NaN          NaN              NaN         NaN      NaN
# 42541        NaN          NaN              NaN         NaN      NaN
#
#        installment grade sub_grade                 emp_title emp_length  \
# 0           162.87     B        B2                       NaN  10+ years
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         5000.0       5000.0           4975.0   36 months   10.65%
# 1         2500.0       2500.0           2500.0   60 months   15.27%
# 2         2400.0       2400.0           2400.0   36 months   15.96%
# 3        10000.0      10000.0          10000.0   36 months   13.49%
# 4         3000.0       3000.0           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 42537     5000.0       5000.0              0.0   36 months    7.75%
# 42538        NaN          NaN              NaN         NaN      NaN
# 42539        NaN          NaN              NaN         NaN      NaN
# 42540        NaN          NaN              NaN         NaN      NaN
# 42541        NaN          NaN              NaN         NaN      NaN
#
#        installment grade sub_grade                 emp_title emp_length  \
# ...

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens', 'hardship_flag',
# ...

# %%
# Columns to keep based on relevance
relevant_columns = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment',
                    'grade', 'sub_grade','emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
                    'issue_d', 'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
                    'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
                    'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
                    'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d',
                    'last_pymnt_amnt', 'last_credit_pull_d', 'pub_rec_bankruptcies']

df1 = df[relevant_columns]
df1
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         5000.0       5000.0           4975.0   36 months   10.65%
# 1         2500.0       2500.0           2500.0   60 months   15.27%
# 2         2400.0       2400.0           2400.0   36 months   15.96%
# 3        10000.0      10000.0          10000.0   36 months   13.49%
# 4         3000.0       3000.0           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 42537     5000.0       5000.0              0.0   36 months    7.75%
# 42538        NaN          NaN              NaN         NaN      NaN
# 42539        NaN          NaN              NaN         NaN      NaN
# 42540        NaN          NaN              NaN         NaN      NaN
# 42541        NaN          NaN              NaN         NaN      NaN
#
#        installment grade sub_grade                 emp_title emp_length  \
# 0           162.87     B        B2                       NaN  10+ years
# ...

# %%
df1.drop('recoveries', axis=1, inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\3731834020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('recoveries', axis=1, inplace=True)

# %%
df1.drop("total_pymnt_inv", axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\3563074481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("total_pymnt_inv", axis=1,inplace=True)

# %%
df1
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         5000.0       5000.0           4975.0   36 months   10.65%
# 1         2500.0       2500.0           2500.0   60 months   15.27%
# 2         2400.0       2400.0           2400.0   36 months   15.96%
# 3        10000.0      10000.0          10000.0   36 months   13.49%
# 4         3000.0       3000.0           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 42537     5000.0       5000.0              0.0   36 months    7.75%
# 42538        NaN          NaN              NaN         NaN      NaN
# 42539        NaN          NaN              NaN         NaN      NaN
# 42540        NaN          NaN              NaN         NaN      NaN
# 42541        NaN          NaN              NaN         NaN      NaN
#
#        installment grade sub_grade                 emp_title emp_length  \
# 0           162.87     B        B2                       NaN  10+ years
# ...

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0         5000.0       5000.0           4975.0   36 months   10.65%
# 1         2500.0       2500.0           2500.0   60 months   15.27%
# 2         2400.0       2400.0           2400.0   36 months   15.96%
# 3        10000.0      10000.0          10000.0   36 months   13.49%
# 4         3000.0       3000.0           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 42537     5000.0       5000.0              0.0   36 months    7.75%
# 42538        NaN          NaN              NaN         NaN      NaN
# 42539        NaN          NaN              NaN         NaN      NaN
# 42540        NaN          NaN              NaN         NaN      NaN
# 42541        NaN          NaN              NaN         NaN      NaN
#
#        installment grade sub_grade                 emp_title emp_length  \
# 0           162.87     B        B2                       NaN  10+ years
# ...

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1.drop("total_rec_int",axis=1, inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\1505485394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("total_rec_int",axis=1, inplace=True)

# %%
df1.drop("total_rec_late_fee",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\3053064784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("total_rec_late_fee",axis=1,inplace=True)

# %%
df1.drop("collection_recovery_fee",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\3176442566.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("collection_recovery_fee",axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1.drop("total_rec_prncp",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\969239017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("total_rec_prncp",axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1.drop("out_prncp",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\486438694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("out_prncp",axis=1,inplace=True)

# %%
df1.drop("out_prncp_inv",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\977653263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("out_prncp_inv",axis=1,inplace=True)

# %%
df1.drop("total_pymnt",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\1318017101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("total_pymnt",axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'last_pymnt_d',
#        'last_pymnt_amnt', 'last_credit_pull_d', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1.drop("last_pymnt_d",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\166731250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("last_pymnt_d",axis=1,inplace=True)

# %%
df1.drop("last_pymnt_amnt",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2182131808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("last_pymnt_amnt",axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'last_credit_pull_d',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df1.drop("last_credit_pull_d",axis=1,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\435839110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop("last_credit_pull_d",axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
def preprocess_loan_status(status):
    if isinstance(status, str):
        return status.replace('Does not meet the credit policy. Status:', '')
    else:
        return status

df1['loan_status'] = df1['loan_status'].apply(preprocess_loan_status)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2416973177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['loan_status'] = df1['loan_status'].apply(preprocess_loan_status)

# %%
# Remove rows where all columns are empty
df1.dropna(how='all', inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2356289318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(how='all', inplace=True)

# %%
df1.to_csv("LC_Loan_Modified.csv", index=False)

# %%
df1.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'purpose', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'pub_rec_bankruptcies'],
#       dtype='object')
